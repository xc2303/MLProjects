# %% [markdown]
# ## Can you use the following data to build....?
# 1. A model with an embedding layer and dense layers (but w/ no layers meant for sequential data)
# 2.  A model using Conv1d Layers
# 3.  A model with one sequential layer (LSTM or GRU)
# 4. A model with stacked sequential layers (LSTM or GRU)
# 5. A model with bidirectional sequential layers
#
# ### After choosing a model, feed it some realistic tweets that are not from your training data to see if it returns meaningful/useful results.

# %% [markdown]
# •	Citation of paper providing original dataset:  Shahi, Gautam Kishore, Anne Dirkson, and Tim A. Majchrzak. "An exploratory study of covid-19 misinformation on twitter." Online Social Networks and Media 22 (2021): 100104.

# %% [markdown]
# ## Import Data

# %%
#Source:Fighting an Infodemic: COVID-19 Fake News Dataset, https://github.com/diptamath/covid_fake_news,https://arxiv.org/abs/2011.03327 

import pandas as pd
trainingdata=pd.read_csv("https://raw.githubusercontent.com/diptamath/covid_fake_news/main/data/Constraint_Train.csv", usecols = ['tweet','label'])
testdata=pd.read_csv("https://raw.githubusercontent.com/diptamath/covid_fake_news/main/data/english_test_with_labels.csv", usecols = ['tweet','label'])

trainingdata
# Out:
#                                                   tweet label
# 0     The CDC currently reports 99031 deaths. In gen...  real
# 1     States reported 1121 deaths a small rise from ...  real
# 2     Politically Correct Woman (Almost) Uses Pandem...  fake
# 3     #IndiaFightsCorona: We have 1524 #COVID testin...  real
# 4     Populous states can generate large case counts...  real
# ...                                                 ...   ...
# 6415  A tiger tested positive for COVID-19 please st...  fake
# 6416  ???Autopsies prove that COVID-19 is??� a blood...  fake
# 6417  _A post claims a COVID-19 vaccine has already ...  fake
# 6418  Aamir Khan Donate 250 Cr. In PM Relief Cares Fund  fake
# 6419  It has been 93 days since the last case of COV...  real
#
# [6420 rows x 2 columns]

# %% [markdown]
# •	Present examples of tweets from the dataset that demonstrate real information or misinformation.

# %%
contains_real = trainingdata['label'].str.contains("real")

#contains_fake = trainingdata['label'].str.contains("fake")

filtered_real = trainingdata[contains_real]
filtered_real.head()
# Out:
#                                                tweet label
# 0  The CDC currently reports 99031 deaths. In gen...  real
# 1  States reported 1121 deaths a small rise from ...  real
# 3  #IndiaFightsCorona: We have 1524 #COVID testin...  real
# 4  Populous states can generate large case counts...  real
# 5  Covid Act Now found "on average each person in...  real

# %%
contains_fake = trainingdata['label'].str.contains("fake")

filtered_fake = trainingdata[contains_fake]
filtered_fake.head()
# Out:
#                                                 tweet label
# 2   Politically Correct Woman (Almost) Uses Pandem...  fake
# 7   Obama Calls Trump’s Coronavirus Response A Cha...  fake
# 8   ???Clearly, the Obama administration did not l...  fake
# 9   Retraction—Hydroxychloroquine or chloroquine w...  fake
# 11  The NBA is poised to restart this month. In Ma...  fake

# %% [markdown]
# •	Discuss the dataset in general terms and describe why building a predictive model using this data might be practically useful.  Who could benefit from a model like this? Explain.

# %% [markdown]
# The dataset contains 6420 rows and 2 columns. The tweet column contains text information of tweets while the label means the information being tweeted is real or fake.
#
# Building a predictive model using this data will help predict the real and fake information in past and real time tweets.
#
# Social network content security team will benefit a model like this, since they can closely monitor what is being said on the platform, and stop the spread of misinformation early on to avoid mass distribution. e.g. People might be misguided because of some misinformation on the internet about inaccurate virus information which could harm public health system. Content supervision team will be able to flag inaccurate content more promptly and secure a safer internet environment.

# %% [markdown]
# ## Define Preprocessor

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Build vocabulary from training text data
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(trainingdata.tweet)

# preprocessor tokenizes words and makes sure all documents have the same length
def preprocessor(data, maxlen, max_words):

    sequences = tokenizer.texts_to_sequences(data)

    word_index = tokenizer.word_index
    X = pad_sequences(sequences, maxlen=maxlen)

    return X

# %% [markdown]
# ## Prepare Train and Test Data

# %%
# tokenize and pad X data
X_train = preprocessor(trainingdata.tweet, maxlen=40, max_words=10000)
X_test = preprocessor(testdata.tweet, maxlen=40, max_words=10000)

# ohe encode Y data
y_train = pd.get_dummies(trainingdata.label)
y_test = pd.get_dummies(testdata.label)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6420, 40)
# (2140, 40)

# %% [markdown]
# ## Train Placeholder Model

# %%
from tensorflow.keras.layers import Dense, Embedding,Flatten
from tensorflow.keras.models import Sequential

# replace this model with the architectures from the task description
model = Sequential()
model.add(Embedding(10000, 16, input_length=40))
model.add(Flatten())
model.add(Dense(2, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Epoch 1/10
# 161/161 [==============================] - 1s 5ms/step - loss: 0.5773 - acc: 0.7080 - val_loss: 0.3802 - val_acc: 0.8310
# Epoch 2/10
# 161/161 [==============================] - 0s 2ms/step - loss: 0.3249 - acc: 0.8604 - val_loss: 0.2698 - val_acc: 0.8879
# Epoch 3/10
# 161/161 [==============================] - 0s 2ms/step - loss: 0.2086 - acc: 0.9206 - val_loss: 0.2235 - val_acc: 0.9073
# Epoch 4/10
# 161/161 [==============================] - 0s 2ms/step - loss: 0.1324 - acc: 0.9536 - val_loss: 0.1960 - val_acc: 0.9252
# Epoch 5/10
# 161/161 [==============================] - 0s 2ms/step - loss: 0.1042 - acc: 0.9662 - val_loss: 0.1828 - val_acc: 0.9245
# Epoch 6/10
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0843 - acc: 0.9715 - val_loss: 0.1744 - val_acc: 0.9299
# Epoch 7/10
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0603 - acc: 0.9810 - val_loss: 0.1707 - val_acc: 0.9322
# Epoch 8/10
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0468 - acc: 0.9861 - val_loss: 0.1723 - val_acc: 0.9283
# Epoch 9/10
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0357 - acc: 0.9897 - val_loss: 0.1702 - val_acc: 0.9338
# Epoch 10/10
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0297 - acc: 0.9911 - val_loss: 0.1759 - val_acc: 0.9307

# %%
# format y_pred as labels 
y_pred = model.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:10]
# Out:
# ['real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real']

# %% [markdown]
# # build models

# %%
# tokenize and pad X data
X_train = preprocessor(trainingdata.tweet, maxlen=40, max_words=10000)
X_test = preprocessor(testdata.tweet, maxlen=40, max_words=10000)

# ohe encode Y data
y_train = pd.get_dummies(trainingdata.label)
y_test = pd.get_dummies(testdata.label)

# %%
# Example 1: simple RNN
from tensorflow.keras.layers import SimpleRNN, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN

model_1 = Sequential()
model_1.add(Embedding(10000, 32, input_length=40))
model_1.add(SimpleRNN(32))
model_1.add(Dense(2, activation='sigmoid'))

model_1.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model_1.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)

# Small training data.  Increase for model improvement
# Out:
# Epoch 1/10
# 161/161 [==============================] - 3s 11ms/step - loss: 0.5561 - acc: 0.7348 - val_loss: 0.3408 - val_acc: 0.8653
# Epoch 2/10
# 161/161 [==============================] - 1s 9ms/step - loss: 0.2333 - acc: 0.9142 - val_loss: 0.2301 - val_acc: 0.9042
# Epoch 3/10
# 161/161 [==============================] - 1s 9ms/step - loss: 0.1381 - acc: 0.9505 - val_loss: 0.2552 - val_acc: 0.8941
# Epoch 4/10
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0799 - acc: 0.9715 - val_loss: 0.2869 - val_acc: 0.8793
# Epoch 5/10
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0501 - acc: 0.9828 - val_loss: 0.2121 - val_acc: 0.9252
# Epoch 6/10
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0278 - acc: 0.9922 - val_loss: 0.2137 - val_acc: 0.9237
# Epoch 7/10
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0172 - acc: 0.9946 - val_loss: 0.2464 - val_acc: 0.9260
# Epoch 8/10
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0077 - acc: 0.9979 - val_loss: 0.2861 - val_acc: 0.9058
# Epoch 9/10
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0039 - acc: 0.9988 - val_loss: 0.3130 - val_acc: 0.9104
# Epoch 10/10
# 161/161 [==============================] - 1s 9ms/step - loss: 0.0037 - acc: 0.9985 - val_loss: 0.3552 - val_acc: 0.9058

# %%
# format y_pred as labels 
y_pred = model_1.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:10]
# Out:
# ['real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real']

# %%
# Example 2: Stacked RNN layers

model_2 = Sequential()
model_2.add(Embedding(10000, 32, input_length=40))
model_2.add(LSTM(32, return_sequences=True))
model_2.add(SimpleRNN(32, return_sequences=True))
model_2.add(SimpleRNN(32, return_sequences=True))
model_2.add(SimpleRNN(32))
model_2.add(Dense(2, activation='sigmoid'))

model_2.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model_2.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)

# Small training data.  Increase for model improvement
# Out:
# Epoch 1/10
# 161/161 [==============================] - 11s 42ms/step - loss: 0.4775 - acc: 0.7731 - val_loss: 0.2824 - val_acc: 0.8879
# Epoch 2/10
# 161/161 [==============================] - 6s 38ms/step - loss: 0.1428 - acc: 0.9497 - val_loss: 0.2019 - val_acc: 0.9167
# Epoch 3/10
# 161/161 [==============================] - 6s 37ms/step - loss: 0.0782 - acc: 0.9727 - val_loss: 0.2933 - val_acc: 0.9104
# Epoch 4/10
# 161/161 [==============================] - 6s 37ms/step - loss: 0.0424 - acc: 0.9856 - val_loss: 0.2275 - val_acc: 0.9245
# Epoch 5/10
# 161/161 [==============================] - 6s 37ms/step - loss: 0.0225 - acc: 0.9915 - val_loss: 0.2608 - val_acc: 0.9361
# Epoch 6/10
# 161/161 [==============================] - 6s 37ms/step - loss: 0.0127 - acc: 0.9957 - val_loss: 0.3964 - val_acc: 0.8956
# Epoch 7/10
# 161/161 [==============================] - 6s 37ms/step - loss: 0.0070 - acc: 0.9982 - val_loss: 0.3701 - val_acc: 0.9322
# Epoch 8/10
# 161/161 [==============================] - 6s 37ms/step - loss: 0.0015 - acc: 0.9996 - val_loss: 0.5002 - val_acc: 0.9213
# Epoch 9/10
# 161/161 [==============================] - 6s 37ms/step - loss: 0.0011 - acc: 0.9999 - val_loss: 0.4784 - val_acc: 0.9104
# Epoch 10/10
# 161/161 [==============================] - 6s 37ms/step - loss: 0.0040 - acc: 0.9990 - val_loss: 0.5278 - val_acc: 0.9307

# %%
# format y_pred as labels 
y_pred = model_2.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:10]
# Out:
# ['real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real']

# %%
# Example 3: LSTM layer

model_3 = Sequential()
model_3.add(Embedding(10000, 32, input_length=40))
model_3.add(LSTM(32))
model_3.add(Dense(2, activation='softmax'))

model_3.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model_3.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)

# Small training data.  Increase for model improvement
# Out:
# Epoch 1/10
# 161/161 [==============================] - 6s 21ms/step - loss: 0.5480 - acc: 0.7579 - val_loss: 0.2712 - val_acc: 0.8988
# Epoch 2/10
# 161/161 [==============================] - 3s 19ms/step - loss: 0.2214 - acc: 0.9223 - val_loss: 0.2155 - val_acc: 0.9174
# Epoch 3/10
# 161/161 [==============================] - 3s 19ms/step - loss: 0.1203 - acc: 0.9616 - val_loss: 0.1909 - val_acc: 0.9182
# Epoch 4/10
# 161/161 [==============================] - 3s 19ms/step - loss: 0.0851 - acc: 0.9695 - val_loss: 0.2057 - val_acc: 0.9299
# Epoch 5/10
# 161/161 [==============================] - 3s 19ms/step - loss: 0.0527 - acc: 0.9825 - val_loss: 0.2215 - val_acc: 0.9307
# Epoch 6/10
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0430 - acc: 0.9852 - val_loss: 0.2283 - val_acc: 0.9330
# Epoch 7/10
# 161/161 [==============================] - 3s 18ms/step - loss: 0.0374 - acc: 0.9887 - val_loss: 0.2701 - val_acc: 0.9260
# Epoch 8/10
# 161/161 [==============================] - 3s 19ms/step - loss: 0.0387 - acc: 0.9834 - val_loss: 0.2621 - val_acc: 0.9315
# Epoch 9/10
# 161/161 [==============================] - 3s 19ms/step - loss: 0.0259 - acc: 0.9922 - val_loss: 0.2613 - val_acc: 0.9229
# Epoch 10/10
# 161/161 [==============================] - 3s 19ms/step - loss: 0.0193 - acc: 0.9924 - val_loss: 0.2418 - val_acc: 0.9213

# %%
# format y_pred as labels 
y_pred = model_3.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:10]
# Out:
# ['real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real']

# %%
#Example 4: Bidirectional LSTM
from tensorflow.keras.layers import Embedding, Bidirectional

model_4 = Sequential()
model_4.add(Embedding(10000, 32, input_length=40))
model_4.add(Bidirectional(LSTM(32)))
model_4.add(Dense(2, activation='sigmoid'))

model_4.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model_4.fit(X_train, y_train, 
                      epochs=10, 
                      batch_size=128, 
                      validation_split=0.2)
# Out:
# Epoch 1/10
# 41/41 [==============================] - 6s 64ms/step - loss: 0.6052 - acc: 0.6822 - val_loss: 0.3424 - val_acc: 0.8536
# Epoch 2/10
# 41/41 [==============================] - 2s 43ms/step - loss: 0.2841 - acc: 0.8830 - val_loss: 0.2272 - val_acc: 0.9065
# Epoch 3/10
# 41/41 [==============================] - 2s 42ms/step - loss: 0.1410 - acc: 0.9497 - val_loss: 0.2257 - val_acc: 0.9159
# Epoch 4/10
# 41/41 [==============================] - 2s 42ms/step - loss: 0.0840 - acc: 0.9731 - val_loss: 0.2109 - val_acc: 0.9174
# Epoch 5/10
# 41/41 [==============================] - 2s 42ms/step - loss: 0.0463 - acc: 0.9839 - val_loss: 0.2684 - val_acc: 0.9182
# Epoch 6/10
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0333 - acc: 0.9887 - val_loss: 0.2577 - val_acc: 0.9198
# Epoch 7/10
# 41/41 [==============================] - 2s 42ms/step - loss: 0.0240 - acc: 0.9934 - val_loss: 0.2686 - val_acc: 0.9283
# Epoch 8/10
# 41/41 [==============================] - 2s 42ms/step - loss: 0.0137 - acc: 0.9957 - val_loss: 0.2921 - val_acc: 0.9245
# Epoch 9/10
# 41/41 [==============================] - 2s 42ms/step - loss: 0.0099 - acc: 0.9962 - val_loss: 0.3009 - val_acc: 0.9283
# Epoch 10/10
# 41/41 [==============================] - 2s 43ms/step - loss: 0.0046 - acc: 0.9993 - val_loss: 0.3272 - val_acc: 0.9221

# %%
# format y_pred as labels 
y_pred = model_4.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:10]
# Out:
# ['real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real']

# %%
#Example 5: LSTM with dropout layer
model_5 = Sequential()
model_5.add(Embedding(10000, 32, input_length=40))
model_5.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2)) 
model_5.add(Dense(2, activation='sigmoid'))

# try using different optimizers and different optimizer configs

model_5.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model_5.fit(X_train, y_train,
                    epochs=15,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Epoch 1/15
# 161/161 [==============================] - 17s 89ms/step - loss: 0.5165 - acc: 0.7585 - val_loss: 0.2957 - val_acc: 0.8824
# Epoch 2/15
# 161/161 [==============================] - 14s 87ms/step - loss: 0.2105 - acc: 0.9221 - val_loss: 0.1979 - val_acc: 0.9198
# Epoch 3/15
# 161/161 [==============================] - 14s 87ms/step - loss: 0.1316 - acc: 0.9512 - val_loss: 0.3286 - val_acc: 0.8949
# Epoch 4/15
# 161/161 [==============================] - 14s 87ms/step - loss: 0.0925 - acc: 0.9671 - val_loss: 0.2155 - val_acc: 0.9237
# Epoch 5/15
# 161/161 [==============================] - 14s 87ms/step - loss: 0.0686 - acc: 0.9725 - val_loss: 0.2315 - val_acc: 0.9252
# Epoch 6/15
# 161/161 [==============================] - 14s 88ms/step - loss: 0.0623 - acc: 0.9801 - val_loss: 0.1962 - val_acc: 0.9330
# Epoch 7/15
# 161/161 [==============================] - 14s 87ms/step - loss: 0.0434 - acc: 0.9841 - val_loss: 0.1727 - val_acc: 0.9330
# Epoch 8/15
# 161/161 [==============================] - 14s 87ms/step - loss: 0.0366 - acc: 0.9881 - val_loss: 0.1684 - val_acc: 0.9338
# Epoch 9/15
# 161/161 [==============================] - 14s 87ms/step - loss: 0.0360 - acc: 0.9875 - val_loss: 0.2574 - val_acc: 0.9322
# Epoch 10/15
# 161/161 [==============================] - 14s 87ms/step - loss: 0.0288 - acc: 0.9901 - val_loss: 0.2343 - val_acc: 0.9408
# Epoch 11/15
# 161/161 [==============================] - 14s 87ms/step - loss: 0.0156 - acc: 0.9939 - val_loss: 0.2368 - val_acc: 0.9338
# Epoch 12/15
# 161/161 [==============================] - 14s 88ms/step - loss: 0.0205 - acc: 0.9932 - val_loss: 0.2769 - val_acc: 0.9369
# Epoch 13/15
# 161/161 [==============================] - 14s 88ms/step - loss: 0.0181 - acc: 0.9946 - val_loss: 0.2405 - val_acc: 0.9315
# Epoch 14/15
# 161/161 [==============================] - 14s 88ms/step - loss: 0.0154 - acc: 0.9949 - val_loss: 0.3454 - val_acc: 0.9315
# Epoch 15/15
# 161/161 [==============================] - 14s 87ms/step - loss: 0.0107 - acc: 0.9974 - val_loss: 0.2936 - val_acc: 0.9307

# %%
model_5.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 40, 32)            320000
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               82432
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 402,690
# Trainable params: 402,690
# Non-trainable params: 0
# _________________________________________________________________

# %%
# format y_pred as labels 
y_pred = model_5.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:10]
# Out:
# ['real',
#  'fake',
#  'fake',
#  'real',
#  'real',
#  'real',
#  'real',
#  'fake',
#  'real',
#  'real']

# %%
# Use 1D Conv layer rather than RNN or LSTM or GRU to fit model
# Why? Much lighter model to fit. Here we are training on the full dataset.  If you try
# to build a model using LSTM code after running this one it will be much slower.

from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import SimpleRNN, LSTM,Embedding

model_6 = Sequential()
model_6.add(layers.Embedding(10000, 8, input_length=40))
model_6.add(layers.Conv1D(32, 7, activation='relu')) 
model_6.add(layers.MaxPooling1D(5)) #
model_6.add(layers.Conv1D(32, 6, activation='relu'))
model_6.add(layers.GlobalMaxPooling1D())
model_6.add(layers.Dense(2))

model_6.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 40, 8)             80000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 34, 32)            1824
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 6, 32)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1, 32)             6176
# _________________________________________________________________
# global_max_pooling1d (Global (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 88,066
# Trainable params: 88,066
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_6.compile(optimizer=RMSprop(lr=1e-4),
              loss='binary_crossentropy',
              metrics=['acc'])
history = model_6.fit(X_train, y_train,
                    epochs=50,
                    batch_size=128,
                    validation_split=0.2)
# Out:
# Epoch 1/50
# 41/41 [==============================] - 1s 13ms/step - loss: 6.6617 - acc: 0.5308 - val_loss: 4.9113 - val_acc: 0.4852
# Epoch 2/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.9619 - acc: 0.4679 - val_loss: 4.7407 - val_acc: 0.4852
# Epoch 3/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.7953 - acc: 0.4694 - val_loss: 4.5781 - val_acc: 0.4852
# Epoch 4/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.6316 - acc: 0.4714 - val_loss: 4.4456 - val_acc: 0.4852
# Epoch 5/50
# 41/41 [==============================] - 0s 9ms/step - loss: 4.4564 - acc: 0.4802 - val_loss: 4.3613 - val_acc: 0.4852
# Epoch 6/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.4421 - acc: 0.4716 - val_loss: 4.3007 - val_acc: 0.4852
# Epoch 7/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.3562 - acc: 0.4765 - val_loss: 4.2640 - val_acc: 0.4852
# Epoch 8/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.3478 - acc: 0.4732 - val_loss: 4.2408 - val_acc: 0.4852
# Epoch 9/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.3638 - acc: 0.4684 - val_loss: 4.2255 - val_acc: 0.4852
# Epoch 10/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.2715 - acc: 0.4783 - val_loss: 4.2151 - val_acc: 0.4852
# Epoch 11/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.2757 - acc: 0.4768 - val_loss: 4.2072 - val_acc: 0.4852
# Epoch 12/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.3360 - acc: 0.4668 - val_loss: 4.2002 - val_acc: 0.4868
# Epoch 13/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.2601 - acc: 0.4777 - val_loss: 4.1923 - val_acc: 0.4922
# Epoch 14/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.2103 - acc: 0.4920 - val_loss: 4.1841 - val_acc: 0.5078
# Epoch 15/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.2142 - acc: 0.5028 - val_loss: 4.1775 - val_acc: 0.5319
# Epoch 16/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.2405 - acc: 0.5165 - val_loss: 4.1687 - val_acc: 0.5483
# Epoch 17/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.2083 - acc: 0.5372 - val_loss: 4.1653 - val_acc: 0.5569
# Epoch 18/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.2417 - acc: 0.5442 - val_loss: 4.1641 - val_acc: 0.5794
# Epoch 19/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.1461 - acc: 0.5799 - val_loss: 4.1561 - val_acc: 0.5857
# Epoch 20/50
# 41/41 [==============================] - 0s 9ms/step - loss: 4.2300 - acc: 0.5723 - val_loss: 4.1505 - val_acc: 0.5950
# Epoch 21/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.1357 - acc: 0.6003 - val_loss: 4.1578 - val_acc: 0.6153
# Epoch 22/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.2245 - acc: 0.6168 - val_loss: 4.1543 - val_acc: 0.6153
# Epoch 23/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.1130 - acc: 0.6338 - val_loss: 4.1479 - val_acc: 0.6456
# Epoch 24/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.1455 - acc: 0.6515 - val_loss: 4.1485 - val_acc: 0.6628
# Epoch 25/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.1633 - acc: 0.6730 - val_loss: 4.1623 - val_acc: 0.6667
# Epoch 26/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.0810 - acc: 0.6873 - val_loss: 4.1430 - val_acc: 0.6799
# Epoch 27/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.1420 - acc: 0.6963 - val_loss: 4.1403 - val_acc: 0.6838
# Epoch 28/50
# 41/41 [==============================] - 0s 9ms/step - loss: 4.1296 - acc: 0.7127 - val_loss: 4.1419 - val_acc: 0.6916
# Epoch 29/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.0983 - acc: 0.7080 - val_loss: 4.1730 - val_acc: 0.6970
# Epoch 30/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.1246 - acc: 0.7215 - val_loss: 4.1450 - val_acc: 0.7134
# Epoch 31/50
# 41/41 [==============================] - 0s 9ms/step - loss: 4.1014 - acc: 0.7397 - val_loss: 4.1440 - val_acc: 0.7196
# Epoch 32/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.1081 - acc: 0.7446 - val_loss: 4.1408 - val_acc: 0.7188
# Epoch 33/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.1438 - acc: 0.7534 - val_loss: 4.1474 - val_acc: 0.7329
# Epoch 34/50
# 41/41 [==============================] - 0s 9ms/step - loss: 4.1078 - acc: 0.7547 - val_loss: 4.1560 - val_acc: 0.7274
# Epoch 35/50
# 41/41 [==============================] - 0s 9ms/step - loss: 4.1097 - acc: 0.7636 - val_loss: 4.1573 - val_acc: 0.7391
# Epoch 36/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.0808 - acc: 0.7768 - val_loss: 4.1558 - val_acc: 0.7547
# Epoch 37/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.1113 - acc: 0.7829 - val_loss: 4.1539 - val_acc: 0.7586
# Epoch 38/50
# 41/41 [==============================] - 0s 9ms/step - loss: 4.1374 - acc: 0.7954 - val_loss: 4.1531 - val_acc: 0.7601
# Epoch 39/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.0886 - acc: 0.8068 - val_loss: 4.1517 - val_acc: 0.7679
# Epoch 40/50
# 41/41 [==============================] - 0s 9ms/step - loss: 4.1369 - acc: 0.8080 - val_loss: 4.1519 - val_acc: 0.7687
# Epoch 41/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.0635 - acc: 0.8210 - val_loss: 4.1555 - val_acc: 0.7749
# Epoch 42/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.0377 - acc: 0.8212 - val_loss: 4.1685 - val_acc: 0.7656
# Epoch 43/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.0222 - acc: 0.8232 - val_loss: 4.1598 - val_acc: 0.7773
# Epoch 44/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.1255 - acc: 0.8312 - val_loss: 4.1649 - val_acc: 0.7780
# Epoch 45/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.0778 - acc: 0.8314 - val_loss: 4.1697 - val_acc: 0.7897
# Epoch 46/50
# 41/41 [==============================] - 0s 9ms/step - loss: 4.1119 - acc: 0.8339 - val_loss: 4.1647 - val_acc: 0.8037
# Epoch 47/50
# 41/41 [==============================] - 0s 8ms/step - loss: 4.0298 - acc: 0.8499 - val_loss: 4.1900 - val_acc: 0.7897
# Epoch 48/50
# 41/41 [==============================] - 0s 9ms/step - loss: 3.9356 - acc: 0.8582 - val_loss: 4.1759 - val_acc: 0.7983
# Epoch 49/50
# 41/41 [==============================] - 0s 9ms/step - loss: 4.0736 - acc: 0.8515 - val_loss: 4.1847 - val_acc: 0.8084
# Epoch 50/50
# 41/41 [==============================] - 0s 9ms/step - loss: 4.1297 - acc: 0.8556 - val_loss: 4.1808 - val_acc: 0.8107

# %%
# format y_pred as labels 
y_pred = model_6.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:10]
# Out:
# ['real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'fake',
#  'real',
#  'fake',
#  'real',
#  'real']

# %% [markdown]
# Discuss which models performed better and point out relevant hyper-parameter values for successful models:
#
# My best model is the 5th model; it is LSTM with dropout layer. It has 3 layers in total: Embedding, LSTM and Dense. It has 402,690 parameters. The embedding takes in 10,000 32, and input length of 40 as the parameter. LSTM layer has dropout value of 0.2; and dense layer uses sigmoid activation function. It uses optimizer of rmsprop, and loss function of binary_crossentropy.

# %% [markdown]
# ## Submit Model

# %%
# install aimodelshare library
# %%capture
! pip install aimodelshare --upgrade --extra-index-url https://test.pypi.org/simple/

# %%
import aimodelshare as ai
from aimodelshare.aimsonnx import model_to_onnx
from aimodelshare.aimsonnx  import instantiate_model

# %%
# save preprocessor
ai.export_preprocessor(preprocessor,"")

# %%
# save model in onnx format
onnx_model = model_to_onnx(model_5, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("onnx_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())
# Out:
# INFO:tensorflow:Assets written to: /tmp/assets

# %%
# set credentials for modeltoapi function 
# make sure you have uploaded your credentials.txt file
from aimodelshare.aws import set_credentials
api_url = "https://wvr23l2z9i.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=api_url,credential_file="credentials.txt", type="submit_model", manual=False)
# Out:
# AI Model Share login credentials set successfully.
# AWS credentials set successfully.

# %%
# submit model and predictions to competition
ai.submit_model("onnx_model.onnx",
                api_url,
                prediction_submission=predicted_labels,
                preprocessor="preprocessor.zip")
# Out:
# 'Your model has been submitted as model version 77'

# %%
# check leaderboard
data=ai.get_leaderboard(api_url, verbose=3)
ai.leaderboard.stylize_leaderboard(data)
# Out:
# <style  type="text/css" >
# #T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col0,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 95.1%, transparent 95.1%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col1,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 95.1%, transparent 95.1%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col2,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 95.1%, transparent 95.1%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col3,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 95.1%, transparent 95.1%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col4,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col5,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col6,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col7,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col8,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col9,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col10,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col11,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col12,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col13,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col14,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col15,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col16,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col17,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col18,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col19,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col20,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col21,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col22,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col23,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col24,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col25,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col26,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row0_col27,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col4,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col5,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col6,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col7,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col8,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col9,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col10,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col11,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col12,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col13,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col14,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col15,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col16,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col17,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col18,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col19,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col20,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col21,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col22,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col23,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col24,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col25,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col26,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row1_col27,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col4,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col5,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col6,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col7,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col8,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col9,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col10,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col11,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col12,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col13,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col14,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col15,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col16,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col17,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col18,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col19,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col20,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col21,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col22,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col23,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col24,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col25,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col26,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row2_col27,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row3_col4,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row3_col5,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row3_col6,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row3_col7,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row3_col8,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row3_col9,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row3_col10,#T_7f9b9ee8_a093_11eb_bbeb_0242ac1c0002row3_col11,#T_7f9b9ee8_a09 ...

# %%
 # Get best model architecture and view model summary, change version arg as needed
 
 bestmodel = ai.aimsonnx.instantiate_model(api_url, version=61) 

 bestmodel.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_27 (Embedding)     (None, 40, 100)           1000000
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 40, 80)            45120
# _________________________________________________________________
# lstm_37 (LSTM)               (None, 60)                33840
# _________________________________________________________________
# dense_43 (Dense)             (None, 40)                2440
# _________________________________________________________________
# dense_44 (Dense)             (None, 2)                 82
# =================================================================
# Total params: 1,081,482
# Trainable params: 1,081,482
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compare two model versions to see diffs
ai.aimsonnx.compare_models(api_url, version_list=[61,62])
# Out:
# <style  type="text/css" >
# #T_887dfeca_a093_11eb_bbeb_0242ac1c0002row2_col3,#T_887dfeca_a093_11eb_bbeb_0242ac1c0002row3_col0,#T_887dfeca_a093_11eb_bbeb_0242ac1c0002row4_col0{
#             background:  tomato;
#         }</style><table id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model_61_Layer</th>        <th class="col_heading level0 col1" >Model_61_Shape</th>        <th class="col_heading level0 col2" >Model_61_Params</th>        <th class="col_heading level0 col3" >Model_62_Layer</th>        <th class="col_heading level0 col4" >Model_62_Shape</th>        <th class="col_heading level0 col5" >Model_62_Params</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row0_col0" class="data row0 col0" >Embedding</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row0_col1" class="data row0 col1" >(None, 40, 100)</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row0_col2" class="data row0 col2" >1000000</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row0_col3" class="data row0 col3" >Embedding</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row0_col4" class="data row0 col4" >(None, 40, 32)</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row0_col5" class="data row0 col5" >320000.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row1_col0" class="data row1 col0" >Bidirectional</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row1_col1" class="data row1 col1" >(None, 40, 80)</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row1_col2" class="data row1 col2" >45120</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row1_col3" class="data row1 col3" >LSTM</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row1_col4" class="data row1 col4" >(None, 128)</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row1_col5" class="data row1 col5" >82432.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row2_col0" class="data row2 col0" >LSTM</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row2_col1" class="data row2 col1" >(None, 60)</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row2_col2" class="data row2 col2" >33840</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row2_col3" class="data row2 col3" >Dense</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row2_col4" class="data row2 col4" >(None, 2)</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row2_col5" class="data row2 col5" >258.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row3_col0" class="data row3 col0" >Dense</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row3_col1" class="data row3 col1" >(None, 40)</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row3_col2" class="data row3 col2" >2440</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row3_col4" class="data row3 col4" >nan</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row3_col5" class="data row3 col5" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row4_col0" class="data row4 col0" >Dense</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row4_col1" class="data row4 col1" >(None, 2)</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row4_col2" class="data row4 col2" >82</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row4_col4" class="data row4 col4" >nan</td>
#                         <td id="T_887dfeca_a093_11eb_bbeb_0242ac1c0002row4_col5" class="data row4 col5" >nan</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Explain how the model's structure is different from your best model./ Compare summary of your model with top model **
#
#
# Performance:
# The difference between the top model (Version 61) and my model (version 62) is that, the accuracy score is much higher with 95.0% accuracy versus mine: 94.2%; and f1_scroe of 94.99% versus mine: 94.19%.
#
# Layers:
# The best model uses 5 layers in total: Embedding, Bidirectional, LSTM, and 2 Dense layers. The model contains 1,081,482 number of parameters. My model has 3 layers in total: Embedding, LSTM and Dense. It has 402,690 parameters.
#
# Activation and Optimizer:
# The best model used relu, softmax and tanh activation while my model used sigmoid and tanh activation. Both models used RMSprop as optimizer.

# %%
# Fit the best model from the leader board to training data and evaluate it on test data to complete your report.
bestmodel.compile(optimizer='rmsprop', loss='binary_crossentropy',
              metrics=['acc'])

bestmodel.fit(X_train, y_train,batch_size=1,
              epochs = 5, verbose=1,validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 6420/6420 [==============================] - 265s 40ms/step - loss: 0.3854 - acc: 0.8423 - val_loss: 0.2217 - val_acc: 0.9131
# Epoch 2/5
# 6420/6420 [==============================] - 258s 40ms/step - loss: 0.2239 - acc: 0.9268 - val_loss: 0.2453 - val_acc: 0.9304
# Epoch 3/5
# 6420/6420 [==============================] - 258s 40ms/step - loss: 0.1967 - acc: 0.9482 - val_loss: 0.1962 - val_acc: 0.9322
# Epoch 4/5
# 6420/6420 [==============================] - 260s 41ms/step - loss: 0.1705 - acc: 0.9586 - val_loss: 0.2433 - val_acc: 0.9383
# Epoch 5/5
# 6420/6420 [==============================] - 263s 41ms/step - loss: 0.1489 - acc: 0.9680 - val_loss: 0.2277 - val_acc: 0.9238

# %%
import pandas as pd

testdata_own=pd.read_csv("tweets_test.csv", usecols = ['tweets','label'])

testdata_own
# Out:
#                                                tweets label
# 0   Using rtweet package, I was able to find numbe...  fake
# 1   n_id<-get_followers(user[i],n=u$followers_coun...  fake
# 2   for a given user name. like ("Tarun"), but hav...  fake
# 3                     Any suggestion will be helpful.  fake
# 4   We can extract number of tweets by user as bel...  fake
# 5    We can extract number of tweets by user as below  fake
# 6   This topic was automatically closed 7 days aft...  fake
# 7   Hello! Looks like you’re enjoying the discussi...  fake
# 8   mlverse software, covering topics ranging from...  fake
# 9   Patrick Corbin says "I feel good, I feel healt...  real
# 10  D-backs handling the Nats. Suns off to a good ...  real
# 11  The Suns game is on Bally Sports Arizona Plus ...  real

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Build vocabulary from test text data
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(testdata_own.tweets)

# preprocessor tokenizes words and makes sure all documents have the same length
def preprocessor(data, maxlen, max_words):

    sequences = tokenizer.texts_to_sequences(data)

    word_index = tokenizer.word_index
    X = pad_sequences(sequences, maxlen=maxlen)

    return X

# %%
# tokenize and pad X data
X_test_2 = preprocessor(testdata_own.tweets, maxlen=40, max_words=10000)

# ohe encode Y data
y_test_2 = pd.get_dummies(testdata_own.label)

# %%
# y_pred 
y_pred = model_5.predict(X_test_2)
y_pred
# Out:
# array([[3.7288666e-04, 9.9964589e-01],
#        [6.2756044e-01, 3.9685267e-01],
#        [9.8370135e-01, 1.6256303e-02],
#        [7.4199677e-01, 2.6254958e-01],
#        [7.9996109e-01, 2.0854610e-01],
#        [9.2655689e-01, 7.3887110e-02],
#        [3.9740026e-01, 6.2416947e-01],
#        [3.4831464e-03, 9.9706340e-01],
#        [3.3529646e-05, 9.9996978e-01],
#        [1.9299984e-04, 9.9983644e-01],
#        [9.9999958e-01, 3.6463311e-07],
#        [1.1288822e-03, 9.9860704e-01]], dtype=float32)
